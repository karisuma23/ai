# %%
n = 7
is_prime = True

for i in range(2, n):       # 소수는 1과 자기 자신만 갖기 때문에 2부터 n-1까지의 값만 확인하면 된다.
    if n % i == 0:          # 약수이기 때문에 소수가 아니다.
        is_prime = False   
        break               # 하나의 약수만 나와도 소수가 아니기 때문에 for문을 더 할 필요가 없다.
    
if is_prime:
    print(n, '은 소수입니다.')
    
else:
    print(n, '은 합성수입니다.')
# Out:
# 7 은 소수입니다.

# %%
def prime(num): # 함수선언 
    p = [] # 소수값을 저장할 리스트 선언
    for i in range(2, num+1): # 구하려는 소수값을 i에 넣어 입력한 num까지 반복 
        count = True # 소수 판별을 위한 비교식 변수 선언 
        for n in range(2, i): #  2부터 i- 1이 될떄 까지 n = 1씩증가   
            if i % n == 0: #  2부터 ~ i-1  까지 나누어 떨어져서 0이 나오면 약수  
                count = False # 약수가 나와 false 값 저장 소수아님  
                break    # 탈출 맨처음 포문으로 이동 
            if count == True: # count 가 True 일 경우 소수로 판별 
             p.append(i) # p 리스트 변수에 소수로 판별된 i값 추가하기 
    

num = int(input('구하려는 값을 입력하시오')) # 구하려는 소수값 입력받기 
print(prime(num)) # 프라임 함수에 입력받은 num 선언 및 출력
# Out:
# None

# %%
def sosu(b): #1000넣으면 됨 
    count = 0
    for i in range(2,b+1): # 첫번째 루프(i) : 1000까지 모든 숫자
        for j in range(2,i): # 두번째 루프(j) : 2~(i)+1 까지 돌림; 
            if (i % j) == 0 : # if 나머지 0인게 있으면 소수 아님,
                count += 1 
                break # 멈춤 걸어서 두번째 루프를 나갑니다(count 개수만 올려주고여). 2~1000사이 전체 개수에서 count개수 빼주면 소수 개수입니다.
    sosu = (b-1) - count  
    return sosu
b = int(input('구하려는 값을 입력하시오'))    
print(sosu(b))
# Out:
# 구하려는 값을 입력하시오1000
# 168
